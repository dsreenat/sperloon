# %% [markdown]
# # Python Seaborn

# %%
#Importing the necessary Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import sklearn
from sklearn import datasets  ## for imprting Iris Dataset
from string import ascii_letters

# %% [markdown]
# Refferences <br>
# https://seaborn.pydata.org/introduction.html <br>
# https://seaborn.pydata.org/tutorial.html

# %%
#importing the inbuilt datasets in seaborn
Data_A = sns.load_dataset('flights')
Data_B = sns.load_dataset('tips')

# %%
#viewing the first 20 rows of the filghts dataset
Data_A.head(10)
# Out:
#    year      month  passengers
# 0  1949    January         112
# 1  1949   February         118
# 2  1949      March         132
# 3  1949      April         129
# 4  1949        May         121
# 5  1949       June         135
# 6  1949       July         148
# 7  1949     August         148
# 8  1949  September         136
# 9  1949    October         119

# %%
#brief info about flights dataset
Data_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
# year          144 non-null int64
# month         144 non-null category
# passengers    144 non-null int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
#Statistical description about the flights dataset
Data_A.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %% [markdown]
# ### Relplot

# %%
#relplot
sns.relplot(x='passengers',y='month', data=Data_A)

## here x and y, we specify the columns to use from the dataset i.e. flights

# %%
#using hue to add another layer (feature) to the plot
sns.relplot(x='passengers',y='month', data=Data_A,hue='year')

# %%
#another variation of the above 
sns.relplot(x='passengers',y='year', data=Data_A,hue='month')

# %%
#Info about the tips dataset
Data_B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
#Brief Statistical description of the tips dataset
Data_B.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#first 10 lines of the tips dataset
Data_B.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#relplot relating time and the total_amount
sns.relplot(x='time',y='total_bill',data=Data_B,kind='line')

# %%
#relplot relating day and the total_bill amount
sns.relplot(x='day',y='total_bill',data=Data_B,kind='line')

# %% [markdown]
# ### Catplot

# %% [markdown]
# Note: Data used for the catplots are 'tips' dataset stored in Data_B

# %%
#default 
sns.catplot(x='day',y='total_bill',data=Data_B)

# %%
#Boxplot
sns.catplot(x='day',y='total_bill',data=Data_B,kind='box')

# %%
#Violin plot
sns.catplot(x='day',y='total_bill',data=Data_B,kind='violin')

# %%
#Boxen plot
sns.catplot(x='day',y='total_bill',data=Data_B,kind='boxen')

# %%
# Univariate distribution

# %%
#creating random number with 5 as the center of normal distribution 
# loc => center  || scale => standard deviation
c=np.random.normal(loc=5,size=500,scale=2)
sns.distplot(c)

# %%
#importing iris dataset 
iris =pd.read_csv("iris.csv")
iris = pd.DataFrame(iris)

# %%
## Bivariate distribution

# %%
#bivariate distribution using joinplot
sns.jointplot(x=iris.sepal_length, y=iris.sepal_width, kind="kde", color="b");

#various options for keyword 'kind' are as follows, 
#kind{ “scatter” | “reg” | “resid” | “kde” | “hex” }, optional

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2  sentosa
# 1           4.9          3.0           1.4          0.2  sentosa
# 2           4.7          3.2           1.3          0.2  sentosa
# 3           4.6          3.1           1.5          0.2  sentosa
# 4           5.0          3.6           1.4          0.2  sentosa

# %%
# correlation, checking for correlation between the columns of iris dataset
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Note: corr() function calculates the relation of one variablet to all other variables <br>
# if the correlation value is very high (1), it means when onve value increases other increses as well.

# %%
#visually presenting the correlation in a heatmap
sns.heatmap(iris.corr())

# %%
sns.set(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
#PairGrid
Pg1 = sns.PairGrid(iris,hue='species')  ##assigning data
#Pg1 = sns.PairGrid(iris)  ##assigning data
Pg1.map(plt.scatter) ## mappig the function to plor
Pg1.add_legend() ## adding legend

# %%
Pg2 = sns.PairGrid(iris)   ###assigning the data to plot
Pg2 = Pg2.map_upper(sns.scatterplot)  ## function for upper triangle
Pg2 = Pg2.map_lower(sns.kdeplot) ## function for lower triangle
Pg2 = Pg2.map_diag(plt.hist) ## function for diagonal

# %%
Pg3 = sns.PairGrid(iris,hue='species')
Pg3 = Pg3.map_upper(sns.scatterplot)
Pg3 = Pg3.map_lower(sns.kdeplot)
Pg3 = Pg3.map_diag(sns.kdeplot, lw=2)

# %%
# Multigrid

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2  sentosa
# 1           4.9          3.0           1.4          0.2  sentosa
# 2           4.7          3.2           1.3          0.2  sentosa
# 3           4.6          3.1           1.5          0.2  sentosa
# 4           5.0          3.6           1.4          0.2  sentosa

# %%
#FacetGrid
i=sns.FacetGrid(iris,col="species") ##mapping dataset
i.map(plt.hist,"sepal_width")

# %%
i=sns.FacetGrid(iris,col="species") ##mapping dataset
i.map(plt.hist,"sepal_length")

# %%
Data_A.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
j=sns.PairGrid(Data_A)
j.map(plt.scatter,color='g')

# %%
c=sns.color_palette()
sns.palplot(c)
